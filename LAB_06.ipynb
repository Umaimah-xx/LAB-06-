# %% [markdown]
# #LAB~06-IMAGE ENHANCEMENT AND ANALYSIS TECHNIQUES:

# %% [markdown]
# #NOISE REDUCTION

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
image = cv2.imread('/content/drive/MyDrive/DIP_LAB_06/HH-ALPSRP092870670-H2.2_UA.tif', 0)  # Load the TIFF image in grayscale
blurred_image = cv2.GaussianBlur(image, (5, 5), 0)  # Adjust the kernel size as needed
plt.subplot(121), plt.imshow(image, cmap='gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122), plt.imshow(blurred_image, cmap='gray')
plt.title('Denoised Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
cv2.imwrite('denoised_image.tif', blurred_image)
# Out:
# True

# %% [markdown]
# #Color Mapping

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the grayscale image
image = cv2.imread('/content/drive/MyDrive/DIP_LAB_06/HH-ALPSRP092870670-H2.2_UA.tif', 0)

# Apply noise reduction
blurred_image = cv2.GaussianBlur(image, (5, 5), 0)

# Apply a colormap for visualization
colormap_image = cv2.applyColorMap(blurred_image, cv2.COLORMAP_JET)

# Display the color-mapped image
plt.imshow(cv2.cvtColor(colormap_image, cv2.COLOR_BGR2RGB))
plt.title('Denoised Image (Color-Mapped)')
plt.show()

# %% [markdown]
# #Mean Squared Error

# %%
import numpy as np

def mse(image1, image2):
    return np.mean((image1 - image2) ** 2)

original_image = cv2.imread('/content/drive/MyDrive/DIP_LAB_06/HH-ALPSRP092870670-H2.2_UA.tif', 0)
denoised_image = cv2.GaussianBlur(original_image, (5, 5), 0)

mse_value = mse(original_image, denoised_image)
print(f"Mean Squared Error: {mse_value}")
# Out:
# Mean Squared Error: 7.7359585840058696

# %% [markdown]
# #Structural Similarity Index (SSIM)

# %%
from skimage.metrics import structural_similarity as ssim

original_image = cv2.imread('/content/drive/MyDrive/DIP_LAB_06/HH-ALPSRP092870670-H2.2_UA.tif', 0)
denoised_image = cv2.GaussianBlur(original_image, (5, 5), 0)

ssim_value = ssim(original_image, denoised_image)
print(f"Structural Similarity Index (SSIM): {ssim_value}")
# Out:
# Structural Similarity Index (SSIM): 0.9203274639967187

# %% [markdown]
# #Reading Specific Pixel Value

# %%
import cv2
import numpy as np

# # Load the original image
original_image = cv2.imread('/content/drive/MyDrive/DIP_LAB_06/HH-ALPSRP092870670-H2.2_UA.tif', 0)  # Load in grayscale

# # Load the denoised image
denoised_image = cv2.GaussianBlur(original_image, (7, 7), 3)

# Convert the images to NumPy arrays
original_pixels = np.array(original_image)
denoised_pixels = np.array(denoised_image)

# Now you can access the pixel values as NumPy arrays
# For example, to access the pixel value at row 1, column 1:
row, col = 1500, 2000
original_pixel_value = original_pixels[row, col]
denoised_pixel_value = denoised_pixels[row, col]

print(f'Original pixel value at ({row}, {col}): {original_pixel_value}')
print(f'Denoised pixel value at ({row}, {col}): {denoised_pixel_value}')
# Out:
# Original pixel value at (1500, 2000): 16
# Denoised pixel value at (1500, 2000): 20

# %% [markdown]
# #Reading and Printing Specified Range of Pixel Values

# %%
# Define the range of pixels
start_row, end_row = 1000, 1009  # Specify the range of rows
start_col, end_col = 1001, 1009  # Specify the range of columns

# Access the pixel values within the specified range
original_pixel_values = original_pixels[start_row:end_row, start_col:end_col]
denoised_pixel_values = denoised_pixels[start_row:end_row, start_col:end_col]

# Display the pixel values
print(f'Original pixel values in the range ({start_row}:{end_row}, {start_col}:{end_col}):')
print(original_pixel_values)

print(f'\nDenoised pixel values in the range ({start_row}:{end_row}, {start_col}:{end_col}):')
print(denoised_pixel_values)
# Out:
# Original pixel values in the range (1000:1009, 1001:1009):
# [[12 14 21 25 25 21 19 29]
#  [20 13  8 11 16 24 27 19]
#  [12 13 16 20 23 25 27 24]
#  [10  8 13 14 13 17 24 19]
#  [20 19 19 22 18 19 22 24]
#  [33 32 22 17 17 15 19 26]
#  [24 22 19 15 20 18 17 19]
#  [21 19 16 24 20 17 21 26]
#  [12 12 14 15 13  8 14 14]]
#
# Denoised pixel values in the range (1000:1009, 1001:1009):
# [[18 18 19 21 22 23 24 24]
#  [17 17 18 19 20 22 23 24]
#  [17 17 17 18 19 21 22 23]
#  [18 18 18 18 19 20 21 22]
#  [19 19 18 19 19 20 20 21]
#  [19 19 18 18 19 19 19 19]
#  [19 19 19 18 18 19 19 19]
#  [19 19 19 18 18 18 18 19]
#  [19 19 18 17 17 17 18 18]]

# %% [markdown]
# #Print All Values (May Hang System)

# %%
# import cv2
# import numpy as np

# # Load the original grayscale image
# original_image = cv2.imread(r'C:\Users\Ahtasham Ahmed\OneDrive - Higher Education Commission\Desktop\Python\Microwave lab\Data\ALPSRP244140480-H2.2_UA\HH-ALPSRP244140480-H2.2_UA.tif', 0)  # Load in grayscale

# # Load the denoised image
# denoised_image = cv2.imread('path_to_denoised_image.tif', 0)  # Load in grayscale

# # Ensure the images are not None
# if original_image is not None and denoised_image is not None:
#     # Convert the images to NumPy arrays
#     original_pixels = np.array(original_image)
#     denoised_pixels = np.array(denoised_image)

#     # Get image dimensions (height and width)
#     height, width = original_pixels.shape

#     # Iterate through all pixel values in the original image
#     for y in range(height):
#         for x in range(width):
#             original_pixel_value = original_pixels[y, x]
#             denoised_pixel_value = denoised_pixels[y, x]
#             print(f'Original Pixel at (y={y}, x={x}): {original_pixel_value}')
#             print(f'Denoised Pixel at (y={y}, x={x}): {denoised_pixel_value}')

#     # Here, you can also perform any desired analysis or processing on the pixel values
#     # For example, calculate statistics, apply filters, etc.

# else:
#     print("Error: Unable to load image(s). Please check the file paths.")

# %% [markdown]
# #Fourier Transform

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the original grayscale image
original_image = cv2.imread('/content/drive/MyDrive/DIP_LAB_06/HH-ALPSRP092870670-H2.2_UA.tif', 0)

# Load the denoised image
denoised_image = cv2.imread('denoised_image.tif', 0)

# Ensure the images are not None
if original_image is not None and denoised_image is not None:
    # Compute the Fourier transform of the original image
    original_transform = np.fft.fft2(original_image)
    original_transform = np.fft.fftshift(original_transform)
    original_magnitude = np.abs(original_transform)
    original_phase = np.angle(original_transform)

    # Compute the Fourier transform of the denoised image
    denoised_transform = np.fft.fft2(denoised_image)
    denoised_transform = np.fft.fftshift(denoised_transform)
    denoised_magnitude = np.abs(denoised_transform)
    denoised_phase = np.angle(denoised_transform)

     # Print amplitude (magnitude) values for both images
    print("Original Image Amplitude (Magnitude):")
    print(original_magnitude)

    print("Denoised Image Amplitude (Magnitude):")
    print(denoised_magnitude)

    # Print phase values for both images
    print("Original Image Phase:")
    print(original_phase)

    print("Denoised Image Phase:")
    print(denoised_phase)

    # Display the original image and its Fourier transform
    plt.subplot(221), plt.imshow(original_image, cmap='gray')
    plt.title('Original Image'), plt.xticks([]), plt.yticks([])

    plt.subplot(222), plt.imshow(np.log(original_magnitude), cmap='gray')
    plt.title('Original Magnitude Spectrum'), plt.xticks([]), plt.yticks([])

    plt.subplot(223), plt.imshow(original_phase, cmap='gray')
    plt.title('Original Phase Spectrum'), plt.xticks([]), plt.yticks([])

    # Display the denoised image and its Fourier transform
    plt.subplot(224), plt.imshow(denoised_image, cmap='gray')
    plt.title('Denoised Image'), plt.xticks([]), plt.yticks([])

    plt.show()

else:
    print("Error: Unable to load image(s). Please check the file paths.")
# Out:
# Original Image Amplitude (Magnitude):
# [[2584.         2826.39584713 4076.79030497 ... 5879.34273774
#   4076.79030497 2826.39584713]
#  [3060.49810654 4497.16309154 3325.99157313 ... 5140.61426256
#   4238.42580045 3461.57748562]
#  [ 650.87493255 1488.2135165  3664.97558594 ... 3081.76364504
#   2153.43774619 4271.37727188]
#  ...
#  [1957.90643189 2667.61451946 2584.17863296 ... 1845.96303584
#   2578.88560984 1222.77160212]
#  [ 650.87493255 4271.37727188 2153.43774619 ... 2528.73843871
#   3664.97558594 1488.2135165 ]
#  [3060.49810654 3461.57748562 4238.42580045 ... 3669.27801104
#   3325.99157313 4497.16309154]]
# Denoised Image Amplitude (Magnitude):
# [[1159.         1788.64234256  308.64564692 ... 2556.63951011
#    308.64564692 1788.64234256]
#  [1009.85241535 1674.86892344 1532.1846265  ...  611.0059438
#   1878.40112325  991.87886601]
#  [1777.02473193  769.06254455 1021.94147103 ...  956.39875978
#   1072.2357721  1949.69865871]
#  ...
#  [ 679.90699675 1558.2016805  1597.41865901 ...  441.83533542
#   1559.26234375  966.34264612]
#  [1777.02473193 1949.69865871 1072.2357721  ...  499.57381073
#   1021.94147103  769.06254455]
#  [1009.85241535  991.87886601 1878.40112325 ...  271.35454653
#   1532.1846265  1674.86892344]]
# Original Image Phase:
# [[ 3.14159265  0.60740326 -2.78716665 ... -0.8369916   2.78716665
#   -0.60740326]
#  [ 1.59953219  0.60431721 -2.3446274  ...  0.07411655 -0.23501637
#   -2.97849981]
#  [ 2.08839865 -0.09876649  1.63649959 ...  0.08846839 -0.49822303
#    0.08338328]
#  ...
#  [ 1.20372074  1.06133629 -1.73118082 ... -0.88020178 -2.67745703
#    0.12514407]
#  [-2.08839865 -0.08338328  0.49822303 ... -0.2126951  -1.63649959
#    0.09876649]
#  [-1.59953219  2.97849981  0.23501637 ...  2.3768368   2.3446274
#   -0.60431721]]
# Denoised Image Phase:
# [[-3.14159265  2.79609287  2.21504822 ...  1.7453976  -2.21504822
#   -2.79609287]
#  [ 0.90240929 -0.82330856 -0.95293691 ...  0.34981451  2.80233227
#    2.92320714]
#  [ 1.76457564  0.72083448  1.03362306 ... -0.94612645  1.0460165
#    2.17619217]
#  ...
#  [-1.84630336  1.77009459 -1.61242785 ...  1.81239244 -1.42192835
#    0.43328419]
#  [-1.76457564 -2.17619217 -1.0460165  ... -1.12573201 -1.03362306
#   -0.72083448]
#  [-0.90240929 -2.92320714 -2.80233227 ... -2.91788295  0.95293691
#    0.82330856]]
